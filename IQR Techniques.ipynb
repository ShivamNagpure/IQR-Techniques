# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Shivam N Nagpure\Downloads\Heart Diseases\heart.csv")

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(data.Cholesterol)
# Out:
# c:\Users\Shivam N Nagpure\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cholesterol'>

# %%
upper=data.Cholesterol.mean()+3*data.Cholesterol.std()

# %%
lower=data.Cholesterol.mean()-3*data.Cholesterol.std()

# %%
data1=data.select_dtypes(include=[np.number])

# %%
data1
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak
# 0     40        140          289          0    172      0.0
# 1     49        160          180          0    156      1.0
# 2     37        130          283          0     98      0.0
# 3     48        138          214          0    108      1.5
# 4     54        150          195          0    122      0.0
# ..   ...        ...          ...        ...    ...      ...
# 913   45        110          264          0    132      1.2
# 914   68        144          193          1    141      3.4
# 915   57        130          131          0    115      1.2
# 916   57        130          236          0    174      0.0
# 917   38        138          175          0    173      0.0
#
# [918 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope'],
#       dtype='object')

# %%
ninety_percentile=data.quantile(0.9)
ninety_percentile
# Out:
# Age             65.0
# RestingBP      160.0
# Cholesterol    305.0
# FastingBS        1.0
# MaxHR          170.0
# Oldpeak          2.3
# Name: 0.9, dtype: float64

# %%
data1
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak
# 0     40        140          289          0    172      0.0
# 1     49        160          180          0    156      1.0
# 2     37        130          283          0     98      0.0
# 3     48        138          214          0    108      1.5
# 4     54        150          195          0    122      0.0
# ..   ...        ...          ...        ...    ...      ...
# 913   45        110          264          0    132      1.2
# 914   68        144          193          1    141      3.4
# 915   57        130          131          0    115      1.2
# 916   57        130          236          0    174      0.0
# 917   38        138          175          0    173      0.0
#
# [918 rows x 6 columns]

# %%
data1.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000

# %%
upper=data[data.Cholesterol>data.Cholesterol.mean()+3*data.Cholesterol.std()]

# %%
upper
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 76     130              N      0.0     Flat
# 149    125              Y      1.0     Flat
# 616    160              N      1.6     Flat

# %%
for i in range(0,len([data.columns])-1):
    data1[[data1.columns[i]]]=np.where(data1[[data1.columns[i]]>upper,ninety_percentile,data1.columns[i]])

# %%
data1
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak
# 0     40        140          289          0    172      0.0
# 1     49        160          180          0    156      1.0
# 2     37        130          283          0     98      0.0
# 3     48        138          214          0    108      1.5
# 4     54        150          195          0    122      0.0
# ..   ...        ...          ...        ...    ...      ...
# 913   45        110          264          0    132      1.2
# 914   68        144          193          1    141      3.4
# 915   57        130          131          0    115      1.2
# 916   57        130          236          0    174      0.0
# 917   38        138          175          0    173      0.0
#
# [918 rows x 6 columns]
